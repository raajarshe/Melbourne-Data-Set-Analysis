# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
mel=pd.read_csv("melbourne.csv")
mel.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  03-09-2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  03-12-2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  04-02-2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  04-02-2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  04-03-2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
mel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23547 entries, 0 to 23546
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         23547 non-null  object
#  1   Address        23547 non-null  object
#  2   Rooms          23547 non-null  int64
#  3   Type           23547 non-null  object
#  4   Price          18396 non-null  float64
#  5   Method         23547 non-null  object
#  6   SellerG        23547 non-null  object
#  7   Date           23547 non-null  object
#  8   Distance       23546 non-null  float64
#  9   Postcode       23546 non-null  float64
#  10  Bedroom2       19066 non-null  float64
#  11  Bathroom       19063 non-null  float64
#  12  Car            18921 non-null  float64
#  13  Landsize       17410 non-null  float64
#  14  BuildingArea   10018 non-null  float64
#  15  YearBuilt      11540 non-null  float64
#  16  CouncilArea    15656 non-null  object
# ...

# %%
mel.shape
# Out:
# (23547, 21)

# %%
mel.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             5151
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          4481
# Bathroom          4484
# Car               4626
# Landsize          6137
# BuildingArea     13529
# YearBuilt        12007
# CouncilArea       7891
# Lattitude         4304
# Longtitude        4304
# Regionname           1
# Propertycount        1
# dtype: int64

# %%
mel.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  23547.000000  1.839600e+04  23546.000000  23546.000000  19066.000000
# mean       2.976048  1.056697e+06     10.306515   3109.782893      2.951956
# std        0.974501  6.419217e+05      6.016318     94.522190      0.996032
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.330000e+05      6.200000   3047.000000      2.000000
# 50%        3.000000  8.800000e+05      9.500000   3101.000000      3.000000
# 75%        4.000000  1.302000e+06     13.000000   3150.000000      4.000000
# max       12.000000  9.000000e+06     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  19063.000000  18921.000000   17410.000000  10018.000000  11540.000000
# mean       1.570897      1.626235     551.783458    154.527895   1964.636742
# ...

# %%
mel.describe().transpose()
# Out:
#                  count          mean            std          min          25%  \
# Rooms          23547.0  2.976048e+00       0.974501      1.00000       2.0000
# Price          18396.0  1.056697e+06  641921.666710  85000.00000  633000.0000
# Distance       23546.0  1.030651e+01       6.016318      0.00000       6.2000
# Postcode       23546.0  3.109783e+03      94.522190   3000.00000    3047.0000
# Bedroom2       19066.0  2.951956e+00       0.996032      0.00000       2.0000
# Bathroom       19063.0  1.570897e+00       0.712684      0.00000       1.0000
# Car            18921.0  1.626235e+00       0.974048      0.00000       1.0000
# Landsize       17410.0  5.517835e+02    3544.288014      0.00000     181.0000
# BuildingArea   10018.0  1.545279e+02     462.535765      0.00000      95.0000
# YearBuilt      11540.0  1.964637e+03      37.595504   1196.00000    1940.0000
# Lattitude      19243.0 -3.781243e+01       0.079926    -38.18418     -37.8593
# ...

# %%
data_priced = mel[mel.Price.notnull()].drop('Address', axis = 1)

# %%
attributes = [ "Date","Price"]
pd.plotting.scatter_matrix(data_priced[attributes], figsize=(12, 8))
#plt.savefig('matrix.png')
plt.show()

# %%
data_priced.hist(bins=50, figsize=(20,15))
plt.savefig("attribute_histogram_plots")
plt.show()

# %%
mel['Suburb'].value_counts().head(10).plot.bar()

# %%
mel['Rooms'].value_counts().sort_index().plot.bar()

# %%
mel['Price'].value_counts().sort_index().plot.line()

# %%
sns.pairplot(mel, x_vars=['Rooms', 'Distance', 'Landsize', 'Car', 'BuildingArea'], y_vars='Price',height=4, aspect=1, kind='scatter')
plt.show()

# %%
sns.heatmap(mel.corr(), cmap="YlGnBu", annot=True)
plt.figure(figsize=(20,20))
plt.show()

# %%
sns.scatterplot(data=mel, x="Rooms", y="Price", hue="Landsize")

# %%
data_priced = mel[mel.Price.notnull()].drop('Address', axis = 1)

# %%
c_m=mel.corr()

# %%
attributes = [ "Date","Price"]
pd.plotting.scatter_matrix(data_priced[attributes], figsize=(12, 8))
#plt.savefig('matrix.png')
plt.show()

# %%
data_priced.hist(bins=50, figsize=(20,15))
plt.savefig("attribute_histogram_plots")
plt.show()

# %%
sns.regplot(x='Rooms',y='Price',data=mel)

# %%
sns.countplot(x="Postcode", data=data_priced)

# %%
sns.countplot(x="Suburb", data=data_priced)

# %%
f, ax = plt.subplots(figsize=(10, 7))
sns.barplot(x ='Price',y="CouncilArea", hue="Regionname", data=data_priced, palette="nipy_spectral");

# %%
mel['Price'].describe()
# Out:
# count    1.839600e+04
# mean     1.056697e+06
# std      6.419217e+05
# min      8.500000e+04
# 25%      6.330000e+05
# 50%      8.800000e+05
# 75%      1.302000e+06
# max      9.000000e+06
# Name: Price, dtype: float64

# %%
x = 'Price'
sns.set_palette("muted")
sns.distplot(mel[x])
plt.ioff()

# %%
x = 'Rooms'
sns.set_palette("muted")
sns.distplot(mel[x])
plt.ioff()

# %%
x = 'Propertycount'
sns.set_palette("muted")
sns.distplot(mel[x])
plt.ioff()

# %%
x = 'Distance'
sns.set_palette("muted")
sns.distplot(mel[x])
plt.ioff()

# %%
title = 'Count of properties per Region'
sns.countplot(y = mel['Regionname'])
plt.title(title)
plt.ioff()

# %%
title = 'Method type'
sns.countplot(y = mel['Method'])
plt.title(title)
plt.ioff()

# %%
title = 'Housing type'
sns.countplot(y = mel['Type'])
plt.title(title)
plt.ioff()

# %%
title = 'Count as per Council Area'
plt.figure(figsize=(20,10))
sns.countplot(y = mel['CouncilArea'])
plt.title(title)
plt.ioff()

# %%
met2 = mel[mel['Suburb']=='Reservoir']
met2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 629 entries, 8320 to 23403
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         629 non-null    object
#  1   Address        629 non-null    object
#  2   Rooms          629 non-null    int64
#  3   Type           629 non-null    object
#  4   Price          541 non-null    float64
#  5   Method         629 non-null    object
#  6   SellerG        629 non-null    object
#  7   Date           629 non-null    object
#  8   Distance       629 non-null    float64
#  9   Postcode       629 non-null    float64
#  10  Bedroom2       450 non-null    float64
#  11  Bathroom       450 non-null    float64
#  12  Car            450 non-null    float64
#  13  Landsize       415 non-null    float64
#  14  BuildingArea   218 non-null    float64
#  15  YearBuilt      255 non-null    float64
#  16  CouncilArea    374 non-null    object
# ...

# %%
met2.describe()
# Out:
#             Rooms         Price    Distance  Postcode    Bedroom2    Bathroom  \
# count  629.000000  5.410000e+02  629.000000     629.0  450.000000  450.000000
# mean     2.790143  6.788121e+05   11.435294    3073.0    2.748889    1.288889
# std      0.812226  2.158085e+05    0.364806       0.0    0.810049    0.522211
# min      1.000000  2.160000e+05   11.200000    3073.0    0.000000    1.000000
# 25%      2.000000  5.200000e+05   11.200000    3073.0    2.000000    1.000000
# 50%      3.000000  6.680000e+05   11.200000    3073.0    3.000000    1.000000
# 75%      3.000000  8.150000e+05   12.000000    3073.0    3.000000    2.000000
# max      5.000000  1.700000e+06   12.000000    3073.0    5.000000    4.000000
#
#               Car      Landsize  BuildingArea    YearBuilt   Lattitude  \
# count  450.000000    415.000000    218.000000   255.000000  456.000000
# mean     1.804444    568.012048    121.874450  1975.811765  -37.713768
# ...

# %%
met2.describe().transpose()
# Out:
#                count           mean            std          min  \
# Rooms          629.0       2.790143       0.812226       1.0000
# Price          541.0  678812.107209  215808.517828  216000.0000
# Distance       629.0      11.435294       0.364806      11.2000
# Postcode       629.0    3073.000000       0.000000    3073.0000
# Bedroom2       450.0       2.748889       0.810049       0.0000
# Bathroom       450.0       1.288889       0.522211       1.0000
# Car            450.0       1.804444       1.074912       0.0000
# Landsize       415.0     568.012048    2039.318364       0.0000
# BuildingArea   218.0     121.874450      76.675397       1.0000
# YearBuilt      255.0    1975.811765      26.682219    1920.0000
# Lattitude      456.0     -37.713768       0.010217     -37.7328
# Longtitude     456.0     145.009733       0.013477     144.9755
# Propertycount  629.0   21650.000000       0.000000   21650.0000
#
# ...

# %%
title = 'Method type'
sns.countplot(y = met2['Method'])
plt.title(title)
plt.ioff()

# %%
title = 'Housing type'
sns.countplot(y = met2['Type'])
plt.title(title)
plt.ioff()

# %%
title = 'pricing type'
sns.countplot(x = met2['Price'])
plt.title(title)
plt.ioff()
